# %%
import urllib, yfinance as yf, pandas as pd, datetime, io, numpy as np, matplotlib.pyplot as plt, re
from pathlib import Path
from email.parser import BytesParser
from email import policy

size, eps, dt0 = 10, 1.0e-10, datetime.date(2004, 1, 1)

SUFFIX = {"NASDAQ":"", "NYSE":"", "AMEX":"", "NYSEARCA":"", "TSX":".TO", "TSXV":".V", "CSE":".CN", "NEO":".NE", "ASX":".AX", "LSE":".L", "XETR":".DE", "FWB":" .F", "MIL":".MI", "BME":".MC", "SIX":".SW", "OMXSTO":".ST", "OMXHEX":".HE", "OMXCOP":".CO", "OSL":".OL", "VIE":".VI"}
EURONEXT = {"france":".PA", "netherlands":".AS", "belgium":".BR", "portugal":".LS", "ireland":".IR"}

def tickers_yahoo(filename, cur):
    msg = BytesParser(policy=policy.default).parsebytes(Path(filename).read_bytes())
    html = next((p.get_payload(decode=True).decode(errors="ignore") for p in msg.walk() if p.get_content_type() == "text/html"), "")
    res = []
    for line in re.findall(r"<tr.*?</tr>", html, re.S):
        m = re.search(r'data-rowkey="([^:]+):([^\"]+)"', line)
        curs = re.findall(r'currency[^>]*>\s*(?:<!-- -->)?\s*([A-Z]{3})\s*</span>', line)
        if m and len(curs) >= 2 and curs[1] == cur:
            exch, tk = m.groups()
            sfx = next((v for k, v in EURONEXT.items() if k in line), None) if exch == "EURONEXT" else SUFFIX.get(exch)
            if sfx is not None: res.append(tk.replace(".", "-").replace("_", "-").rstrip("-") + sfx)
    return list(dict.fromkeys(res))

def GetHistos(codes, dt):
    f = yf.download(list(codes), period="max", group_by="ticker", auto_adjust=True).xs("Close", axis=1, level=1).astype(float)
    def filter_bad_data(s):
        bad = (s.dropna() / s.dropna().shift()).abs() > 10
        return s.mask(s.index <= bad[bad].index[-1], 0) if bad.any() else s
    return f[f.index.date >= dt].apply(filter_bad_data)

def Trace(cumul, title, legend=None, log=None):
    ax = cumul.plot(figsize=(12, 8), title=title, grid=True, logy=log or False)
    if legend: ax.legend(legend)
    plt.show()

def MomentumStrategy(f, label=""):
    ls_sig = f.columns.tolist()
    ac = np.nan_to_num(f.bfill().values)
    m = f.index.to_period("M")
    dates = list(np.flatnonzero(m[:-1] != m[1:])) + [len(f.index)-1]
    ac_sig, df_sig = ac[dates,:], f.iloc[dates].index
    get_mom = lambda data, d: ((pd.DataFrame(data)-pd.DataFrame(data).rolling(d+1).mean())/(pd.DataFrame(data)+eps)).fillna(0).to_numpy()
    s1, s2 = get_mom(ac, 240)[dates,:], get_mom(ac, 90)[dates,:]
    nt, ns = s1.shape
    w = np.zeros((nt, ns))
    for it in range(1, nt):
        x = s1[it, :]
        ratio = sum(np.sign(x))/(sum(np.sign(abs(x)))+eps)
        inds = np.argsort(x)[::-1]
        for j in range(ns):
            if s2[it, j] > 0: w[it, j] = w[it-1, j]
        for idx in inds:
            if len(np.where(w[it,:])[0]) == size: break
            if s1[it, idx] > 0 and s2[it, idx] > 0 and ratio > 0.1 and ac_sig[it, idx] != 0 and w[it, idx] == 0:
                w[it, idx] = 1.0 / size
    r = pd.DataFrame(ac_sig).pct_change().add(1).fillna(1)
    eq = (pd.DataFrame(w).shift(1).fillna(0) * r).sum(axis=1).add(1 - pd.DataFrame(w).shift(1).fillna(0).sum(axis=1)).cumprod()
    print(f"\n--- {label} Last 10m ---")
    for it in range(max(0, nt-10), nt):
        nn = np.where(w[it,:] != 0)[0]
        nn_sorted = sorted(nn, key=lambda ii: s1[it, ii], reverse=True)
        l = [[ls_sig[ii] + "/" + str(round(float(ac_sig[it, ii]),2))] for ii in nn_sorted]
        print(df_sig[it].strftime("%d/%m/%Y"), "| Eq:", round(float(eq.values[it]), 2), "| Pos:", l)
    return pd.DataFrame({"equity": eq.values}).set_index(df_sig)

# https://www.quantifiedstrategies.com/rotation-strategy-in-gold-and-sp500/
def GoldStrategy(dt):
    data = yf.download(['SPY', 'GLD'], period="max", auto_adjust=True)['Close'].dropna()
    f = data[data.index.date >= dt].resample('ME').last()
    ratio = f['GLD'] / (f['SPY'] + eps)
    ma = ratio.rolling(36).mean()
    w = pd.DataFrame(0.0, index=f.index, columns=['SPY', 'GLD'])
    w['GLD'] = np.where(ratio > ma, 1.0, 0.0)
    w['SPY'] = 1.0 - w['GLD']
    r = f.pct_change().add(1).fillna(1)
    eq = (w.shift(1).fillna(0) * r).sum(axis=1).replace(0, 1).cumprod()
    print("\n--- GOLD Last 10m ---")
    for i in range(max(0, len(f)-10), len(f)):
        pos = {k: round(float(v), 2) for k, v in w.iloc[i][w.iloc[i]>0].to_dict().items()}
        print(f.index[i].strftime("%d/%m/%Y"), "| Eq:", round(float(eq.iloc[i]), 2), "| Pos:", str(pos))
    return eq.to_frame("equity")

# https://cssanalytics.wordpress.com/2025/03/20/the-growth-and-inflation-sector-timing-model/
def SectorStrategy(dt):
    ls_sig = ['SPY', 'XLB', 'XLE', 'XLF', 'XLI', 'XLK', 'XLP', 'XLU', 'XLV']
    f = yf.download(ls_sig, period="max", auto_adjust=True, progress=False)["Close"].ffill().loc[lambda x: x.index.date >= dt].resample("ME").last().dropna()
    inf = (0.5*f['XLE'] + 0.17*f['XLI'] + 0.17*f['XLF'] + 0.16*f['XLB']) / (0.34*f['XLP'] + 0.33*f['XLU'] + 0.33*f['XLV'] + 1e-12)
    weights = pd.DataFrame(0.0, index=f.index, columns=f.columns)
    for l in [12, 24, 36, 48]:
        hi, bull = inf > inf.rolling(l).median(), f['SPY'] > f['SPY'].rolling(l).median()
        weights['XLE'] += np.where(hi & bull, 0.25, 0);  weights['XLV'] += np.where(hi & ~bull, 0.25, 0)
        weights['XLK'] += np.where(~hi & bull, 0.25, 0); weights['XLP'] += np.where(~hi & ~bull, 0.25, 0)
    r = f.pct_change().add(1).fillna(1)
    w_lag = weights.shift(1).fillna(0)
    eq = ((w_lag * r).sum(axis=1) + (1 - w_lag.sum(axis=1))).cumprod()
    print("\n--- SECTOR Last 10m ---")
    for i in range(max(0, len(f)-10), len(f)):
        if weights.iloc[i].sum() > 0:
            pos = {k: round(float(v/weights.iloc[i].sum()), 2) for k, v in weights.iloc[i][weights.iloc[i]>0].to_dict().items()}
        else: pos = "Cash"
        print(f.index[i].strftime("%d/%m/%Y"), "| Eq:", round(float(eq.iloc[i]), 2), "| Pos:", str(pos))
    return eq.to_frame("equity")

# Filter: https://www.cambriainvestments.com/wp-content/uploads/2025/02/20250210.TBillsandChillMostoftheTime.Approved.pdf
def BondStrategy(dt):
    def GetFredMonthly(series_id):
        url = f"https://fred.stlouisfed.org/graph/fredgraph.csv?id={series_id}"
        df = pd.read_csv(url, index_col="observation_date", parse_dates=True, na_values=".")
        return df[series_id].astype(float).ffill().resample("ME").last()
    ls_sig = ['SHY', 'IEF', 'LQD', 'HYG', 'TIP', 'CWB']
    df = yf.download(ls_sig, period="max", auto_adjust=True, progress=False)["Close"].ffill()
    f = df[df.index.date >= dt].resample("ME").last()
    r = f.pct_change()
    mom = (r + r.rolling(3).sum() + r.rolling(6).sum() + r.rolling(12).sum()) / 4.0
    rank = mom.rank(axis=1, ascending=False)
    weights = ((rank <= 3) & (mom > 0)).astype(float) / 3.0
    weights = weights.mul((GetFredMonthly("T10Y3M").reindex(f.index).ffill() > 0).astype(float), axis=0)
    rets = f.pct_change().add(1).fillna(1)
    w_lag = weights.shift(1).fillna(0)
    eq = ((w_lag * rets).sum(axis=1) + (1 - w_lag.sum(axis=1))).cumprod()
    print("\n--- BOND Last 10m ---")
    for i in range(max(0, len(f)-10), len(f)):
        pos = {k: round(float(v), 2) for k, v in weights.iloc[i][weights.iloc[i]>0].to_dict().items()}
        print(f.index[i].strftime("%d/%m/%Y"), "| Eq:", round(float(eq.iloc[i]), 2), "| Pos:", str(pos))
    return eq.to_frame("equity")

# --- Run ---
weights_dict = {"EUR": 0.1, "USD": 0.1, "AUD": 0.1, "GBX": 0.1, "CAD": 0.1, "GOLD": 0.1, "SECT": 0.1, "BOND": 0.3}
files = {"EUR":"STOXX 600 Components – TVC_SXXP Stocks — TradingView.mhtml", "USD":"S&P 500 Index Components – SP_SPX Stocks — TradingView.mhtml", "AUD":"S&P_ASX 200 Index Components – ASX_XJO Stocks — TradingView.mhtml", "GBX":"FTSE 350 Index Components – FTSE_NMX Stocks — TradingView.mhtml", "CAD":"S&P_TSX Composite Index Components – TSX_TSX Stocks — TradingView.mhtml"}
sim_momentum = pd.concat({k: MomentumStrategy(GetHistos(tickers_yahoo(v, k), dt0), k)['equity'] for k, v in files.items()}, axis=1).ffill()
gold_eq = GoldStrategy(dt0).reindex(sim_momentum.index, method='ffill').fillna(1.0)
sect_eq = SectorStrategy(dt0).reindex(sim_momentum.index, method='ffill').fillna(1.0)
bond_eq = BondStrategy(dt0).reindex(sim_momentum.index, method='ffill').fillna(1.0)
sim = pd.concat([sim_momentum, gold_eq.rename(columns={"equity":"GOLD"}), sect_eq.rename(columns={"equity":"SECT"}), bond_eq.rename(columns={"equity":"BOND"})], axis=1).ffill().fillna(1.0)
Trace(sim, "Equities", sim.columns.tolist(), log=True)
weights_series = pd.Series(weights_dict)
weights_series = weights_series / weights_series.sum()
combo = (1 + sim.pct_change(fill_method=None).fillna(0).dot(weights_series[sim.columns])).cumprod().rename("Combo")
Trace(combo.to_frame(), "Combo", ["Combo"], log=True)
r = combo.pct_change(fill_method=None).dropna()
mdd = ((combo.cummax() - combo) / combo.cummax()).max()
print(f"\nMean: {round(100*12*float(r.mean()),2)}% | Stdev: {round(100*12**0.5*float(r.std()),2)}% | Sharpe: {round((12*float(r.mean()))/(12**0.5*float(r.std())),2)} | MaxDD: {round(100*float(mdd),2)}%")
print("\n--- Strategy Coefficients ---")
print(weights_series.to_string())
# Out:
# [*********************100%***********************]  298 of 298 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['
# 20/05/2026 | Eq: 82.8 | Pos: [['TPRO.MI/29.56'], ['AIXA.DE/51.28'], ['NOKIA.HE/11.96'], ['STMMI.MI/53.94'], ['BESI.AS/259.4'], ['SPM.MI/4.49'], ['HOT.DE/477.6'], ['NDA.DE/193.9'], ['NESTE.HE/28.95'], ['NDX1.DE/44.08']]
# [*********************100%***********************]  502 of 502 completed
# --- USD Last 10m ---
# 29/08/2025 | Eq: 202.1 | Pos: [['SATS/61.79'], ['HOOD/104.03'], ['PLTR/156.71'], ['GEV/611.89'], ['CVNA/74.38'], ['JBL/204.64'], ['HWM/173.82'], ['AXON/747.29'], ['COIN/304.54'], ['GILD/110.83']]
# 30/09/2025 | Eq: 223.1 | Pos: [['SATS/76.36'], ['SNDK/112.2'], ['HOOD/143.18'], ['WDC/119.91'], ['PLTR/182.42'], ['GEV/613.82'], ['CVNA/75.45'], ['HWM/195.92'], ['JBL/216.97'], ['COIN/337.49']]
# 31/10/2025 | Eq: 245.01 | Pos: [['SNDK/199.33'], ['WDC/150.02'], ['SATS/74.87'], ['CIEN/189.92'], ['LITE/201.56'], ['HOOD/146.78'], ['PLTR/200.47'], ['HWM/205.62'], ['JBL/220.68'], ['COIN/343.78']]
# 28/11/2025 | Eq: 253.15 | Pos: [['SNDK/223.28'], ['LITE/325.16'], ['WDC/163.12'], ['CIEN/204.21'], ['STX/275.49'], ['SATS/73.29'], ['MU/236.29'], ['WBD/24.0'], ['HOOD/128.49'], ['HWM/204.38']]
# 31/12/2025 | Eq: 282.75 | Pos: [['LITE/368.59'], ['SNDK/237.38'], ['SATS/108.7'], ['CIEN/233.87'], ['MU/285.29'], ['WDC/172.19'], ['WBD/28.82'], ['COHR/184.57'], ['STX/274.91'], ['HWM/204.81']]
# 30/01/2026 | Eq: 370.84 | Pos: [['SNDK/576.25'], ['MU/414.71'], ['WDC/250.11'], ['LITE/391.84'], ['STX/406.98'], ['SATS/113.22'], ['CIEN/251.81'], ['COHR/212.18'], ['WBD/27.54'], ['HWM/207.87']]
# 27/02/2026 | Eq: 441.83 | Pos: [['SNDK/635.36'], ['LITE/700.91'], ['CIEN/348.7'], ['WDC/279.57'], ['MU/412.2'], ['COHR/258.93'], ['STX/407.13'], ['SATS/115.53'], ['WBD/28.17'], ['HWM/262.41']]
# 31/03/2026 | Eq: 426.43 | Pos: [['SNDK/635.34'], ['LITE/702.76'], ['CIEN/388.23'], ['WDC/270.49'], ['SATS/117.07'], ['COHR/238.21'], ['STX/391.76'], ['HWM/230.36']]
# 30/04/2026 | Eq: 560.46 | Pos: [['SNDK/1096.51'], ['LITE/902.32'], ['WDC/434.52'], ['INTC/94.48'], ['CIEN/527.58'], ['STX/673.64'], ['MU/517.16'], ['COHR/319.71'], ['SATS/123.14'], ['HWM/242.93']]
# 19/05/2026 | Eq: 627.34 | Pos: [['SNDK/1383.29'], ['INTC/110.8'], ['MU/698.74'], ['WDC/455.8'], ['LITE/890.09'], ['STX/733.35'], ['CIEN/541.92'], ['COHR/353.63'], ['SATS/136.52'], ['HWM/253.12']]
# [*********************100%***********************]  199 of 199 completed
# --- AUD Last 10m ---
# 29/08/2025 | Eq: 1456.57 | Pos: [['SRL.AX/1.75'], ['EOS.AX/5.8'], ['DRO.AX/3.3'], ['APE.AX/26.78'], ['CDA.AX/30.54'], ['360.AX/46.5'], ['ASB.AX/7.77'], ['LYC.AX/13.87'], ['HUB.AX/108.23'], ['PDI.AX/0.47']]
# 30/09/2025 | Eq: 1960.89 | Pos: [['SRL.AX/5.35'], ['EOS.AX/10.22'], ['DRO.AX/4.66'], ['LYC.AX/16.81'], ['360.AX/53.22'], ['APE.AX/28.02'], ['CDA.AX/29.35'], ['ASB.AX/7.74'], ['PDI.AX/0.44'], ['HUB.AX/100.31']]
# 31/10/2025 | Eq: 1929.03 | Pos: [['SRL.AX/4.5'], ['4DX.AX/1.74'], ['EOS.AX/6.21'], ['APE.AX/33.27'], ['CDA.AX/36.05'], ['WGX.AX/5.32'], ['360.AX/49.76'], ['LYC.AX/15.25'], ['PDI.AX/0.56'], ['HUB.AX/113.64']]
# 28/11/2025 | Eq: 1893.15 | Pos: [['SRL.AX/6.62'], ['4DX.AX/1.71'], ['PLS.AX/4.05'], ['LTR.AX/1.43'], ['WGX.AX/6.1'], ['RSG.AX/1.13'], ['RRL.AX/7.25'], ['PDI.AX/0.63'], ['CDA.AX/30.68'], ['APE.AX/27.82']]
# 31/12/2025 | Eq: 2221.93 | Pos: [['4DX.AX/3.93'], ['SRL.AX/7.89'], ['EOS.AX/9.44'], ['ELV.AX/8.04'], ['PLS.AX/4.22'], ['LTR.AX/1.58'], ['WGX.AX/6.44'], ['RSG.AX/1.23'], ['PDI.AX/0.74'], ['RRL.AX/7.41']]
# 30/01/2026 | Eq: 2339.12 | Pos: [['SRL.AX/10.23'], ['4DX.AX/3.17'], ['EOS.AX/8.68'], ['LTR.AX/1.86'], ['WGX.AX/7.36'], ['PLS.AX/4.29'], ['PDI.AX/0.85'], ['RSG.AX/1.36'], ['RRL.AX/7.91'], ['ELV.AX/6.7']]
# 27/02/2026 | Eq: 2547.86 | Pos: [['4DX.AX/4.0'], ['SRL.AX/7.98'], ['PLS.AX/5.19'], ['PDI.AX/0.98'], ['EOS.AX/8.98'], ['WGX.AX/7.75'], ['ELV.AX/8.16'], ['RSG.AX/1.49'], ['RRL.AX/9.27'], ['LTR.AX/1.71']]
# 31/03/2026 | Eq: 2437.94 | Pos: [['4DX.AX/5.56'], ['SRL.AX/8.79'], ['PLS.AX/5.12'], ['ELV.AX/8.36'], ['RSG.AX/1.39'], ['LTR.AX/1.7'], ['EOS.AX/8.01']]
# 30/04/2026 | Eq: 2750.4 | Pos: [['ELV.AX/13.58'], ['SRL.AX/12.44'], ['PLS.AX/6.02'], ['LTR.AX/2.35']]
# 20/05/2026 | Eq: 2680.01 | Pos: [['SRL.AX/12.44'], ['ELV.AX/11.18'], ['PLS.AX/6.03'], ['LTR.AX/2.16']]
# [*********************100%***********************]  343 of 343 completed
# --- GBX Last 10m ---
# 29/08/2025 | Eq: 155.55 | Pos: [['DSV.TO/4.37'], ['ASM.TO/6.11'], ['SSRM.TO/26.5'], ['VNP.TO/15.02'], ['USA.TO/3.7'], ['LUG.TO/81.53'], ['CLS.TO/267.5'], ['MAU.TO/5.48'], ['SKE.TO/23.02'], ['FFH.TO/2345.19']]
# 30/09/2025 | Eq: 185.61 | Pos: [['USA.TO/5.19'], ['ASM.TO/7.3'], ['DSV.TO/5.16'], ['SSRM.TO/33.98'], ['CLS.TO/342.47'], ['VNP.TO/17.01'], ['MAU.TO/6.77'], ['LUG.TO/88.07'], ['SKE.TO/25.63'], ['FFH.TO/2415.1']]
# 31/10/2025 | Eq: 195.52 | Pos: [['EFR.TO/28.8'], ['CLS.TO/482.87'], ['DSV.TO/5.86'], ['USA.TO/5.58'], ['VNP.TO/20.06'], ['SSRM.TO/31.71'], ['NG.TO/11.62'], ['MAU.TO/6.96'], ['ASM.TO/6.53'], ['LUG.TO/93.13']]
# 28/11/2025 | Eq: 215.8 | Pos: [['DSV.TO/7.72'], ['CLS.TO/480.11'], ['USA.TO/6.23'], ['NG.TO/14.28'], ['MAU.TO/8.49'], ['ASM.TO/7.87'], ['LUG.TO/115.03'], ['VNP.TO/19.89'], ['EFR.TO/20.23'], ['SSRM.TO/32.54']]
# 31/12/2025 | Eq: 215.43 | Pos: [['DSV.TO/8.38'], ['ARIS.TO/22.26'], ['ABRA.TO/10.68'], ['MAU.TO/9.88'], ['USA.TO/7.04'], ['GMIN.TO/41.49'], ['ASM.TO/8.54'], ['NG.TO/12.8'], ['LUG.TO/112.51'], ['CLS.TO/406.01']]
# 30/01/2026 | Eq: 241.72 | Pos: [['USA.TO/10.09'], ['ASM.TO/12.18'], ['MAU.TO/12.24'], ['DSV.TO/9.58'], ['TKO.TO/10.35'], ['EFR.TO/30.45'], ['AAUC.TO/42.97'], ['ABRA.TO/11.91'], ['ARIS.TO/23.56'], ['GMIN.TO/43.17']]
# 27/02/2026 | Eq: 294.64 | Pos: [['USA.TO/13.39'], ['MAU.TO/17.0'], ['ABRA.TO/17.61'], ['ARIS.TO/30.9'], ['DSV.TO/11.27'], ['TKO.TO/12.15'], ['GMIN.TO/55.86'], ['ASM.TO/13.12'], ['AAUC.TO/43.18'], ['EFR.TO/29.13']]
# 31/03/2026 | Eq: 235.13 | Pos: [['MAU.TO/15.83'], ['VNP.TO/31.68'], ['CEU.TO/18.41'], ['TVE.TO/11.5'], ['BTE.TO/6.22'], ['TCL-A.TO/5.22'], ['GMIN.TO/48.82'], ['ARIS.TO/25.83'], ['AAUC.TO/43.12'], ['ABRA.TO/12.59']]
# 30/04/2026 | Eq: 242.05 | Pos: [['EFX.TO/36.45'], ['ABRA.TO/16.08'], ['BTE.TO/6.89'], ['TVE.TO/12.74'], ['ARE.TO/49.96'], ['CEU.TO/19.34'], ['VNP.TO/32.77'], ['BDT.TO/50.09'], ['ATH.TO/11.96'], ['TCL-A.TO/5.31']]
# 19/05/2026 | Eq: 257.23 | Pos: [['VNP.TO/41.76'], ['EFX.TO/38.64'], ['BDT.TO/58.68'], ['BTE.TO/7.32'], ['TVE.TO/13.42'], ['ABRA.TO/16.17'], ['ATH.TO/12.68'], ['ARE.TO/48.29'], ['CEU.TO/18.93'], ['TCL-A.TO/5.28']]
# [*********************100%***********************]  2 of 2 completed
# --- GOLD Last 10m ---
# 31/08/2025 | Eq: 13.72 | Pos: {'GLD': 1.0}
# 30/09/2025 | Eq: 15.33 | Pos: {'GLD': 1.0}
# 31/10/2025 | Eq: 15.87 | Pos: {'GLD': 1.0}
# 30/11/2025 | Eq: 16.73 | Pos: {'GLD': 1.0}
# 31/12/2025 | Eq: 17.09 | Pos: {'GLD': 1.0}
# 31/01/2026 | Eq: 19.19 | Pos: {'GLD': 1.0}
# 28/02/2026 | Eq: 20.86 | Pos: {'GLD': 1.0}
# 31/03/2026 | Eq: 18.55 | Pos: {'GLD': 1.0}
# 30/04/2026 | Eq: 18.27 | Pos: {'GLD': 1.0}
# 31/05/2026 | Eq: 17.74 | Pos: {'GLD': 1.0}
#
# --- SECTOR Last 10m ---
# 31/08/2025 | Eq: 13.14 | Pos: {'XLE': 1.0}
# 30/09/2025 | Eq: 13.1 | Pos: {'XLE': 1.0}
# 31/10/2025 | Eq: 12.92 | Pos: {'XLE': 1.0}
# 30/11/2025 | Eq: 13.26 | Pos: {'XLE': 0.75, 'XLK': 0.25}
# 31/12/2025 | Eq: 13.26 | Pos: {'XLE': 1.0}
# 31/01/2026 | Eq: 15.14 | Pos: {'XLE': 1.0}
# 28/02/2026 | Eq: 16.58 | Pos: {'XLE': 1.0}
# 31/03/2026 | Eq: 18.28 | Pos: {'XLE': 0.75, 'XLV': 0.25}
# 30/04/2026 | Eq: 17.9 | Pos: {'XLE': 1.0}
# 31/05/2026 | Eq: 18.4 | Pos: {'XLE': 1.0}
#
# --- BOND Last 10m ---
# 31/08/2025 | Eq: 2.8 | Pos: {}
# 30/09/2025 | Eq: 2.8 | Pos: {'CWB': 0.33, 'HYG': 0.33, 'LQD': 0.33}
# 31/10/2025 | Eq: 2.83 | Pos: {'CWB': 0.33, 'HYG': 0.33, 'LQD': 0.33}
# 30/11/2025 | Eq: 2.82 | Pos: {'CWB': 0.33, 'IEF': 0.33, 'LQD': 0.33}
# 31/12/2025 | Eq: 2.79 | Pos: {'CWB': 0.33, 'HYG': 0.33, 'IEF': 0.33}
# 31/01/2026 | Eq: 2.84 | Pos: {'CWB': 0.33, 'HYG': 0.33, 'LQD': 0.33}
# 28/02/2026 | Eq: 2.86 | Pos: {'CWB': 0.33, 'IEF': 0.33, 'LQD': 0.33}
# 31/03/2026 | Eq: 2.79 | Pos: {'CWB': 0.33, 'HYG': 0.33, 'SHY': 0.33}
# 30/04/2026 | Eq: 2.91 | Pos: {'CWB': 0.33, 'HYG': 0.33, 'TIP': 0.33}
# 31/05/2026 | Eq: 2.91 | Pos: {'CWB': 0.33, 'HYG': 0.33, 'SHY': 0.33}
# Mean: 17.34% | Stdev: 9.03% | Sharpe: 1.92 | MaxDD: 9.91%
#
# --- Strategy Coefficients ---
# EUR     0.1
# USD     0.1
# AUD     0.1
# GBX     0.1
# CAD     0.1
# GOLD    0.1
# SECT    0.1
# BOND    0.3
